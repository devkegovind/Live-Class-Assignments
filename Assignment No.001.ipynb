# %% [markdown]
# # **ASSIGNMENT**

# %% [markdown]
# 1. Find out all the types of error that we have encountered in our lecture and why? Also include the examples.

# %% [markdown]
# We have encountered following errors in our lecture.
# - 1.Variable Case Sensitive:
# name 'Ten' is not defined.
# Here name ten = 10 is defined.
# - 2.'str' object is not callable.-- This is happening because we are using a variable name that the compiler already recognizes as something different.
# - 3.'int' object is not callable.--The “int object is not callable” error occurs when you declare a variable and name it with a built-in function name such as int() , sum() , max() , and others.
# - 4.unsupported operand type(s) for -: 'int' and 'str'--'str' and 'int'” error is raised when you try to subtract a string from an integer. You solve this error by converting all strings to integers using the int() method before performing a mathematical operation.
# - 5.int A -- in it parenthesis is not provided.
# - 6.invalid literal for int() with base 10: '10.2' -- 10.2 is float but converting to int.
# - 8.invalid literal for int() with base 10: ''-- string is empty.

# %% [markdown]
# 2. Take input A and B and print their sum, mul, div, square of the nos.

# %%
A = int(input("Enter value of A: "))
B = int(input("Enter value of B: ")) 
print(f"Sum of A and B is: {A+B}")
print(f"Multiplication of A and B is: {A*B}")
print(f"Division of A and B is:{A/B}")
print(f"Square of A and B is:{A**2},{B**2}")
# Out:
# Enter value of A: 25
# Enter value of B: 67
# Sum of A and B is: 92
# Multiplication of A and B is: 1675
# Division of A and B is:0.373134328358209
# Square of A and B is:625,4489

# %% [markdown]
# 3. How many reserve keywords are there in python and why we should not use them as a variable name.
# - In python their are 35 keywords.
# - You cannot use keywords as variable names. It's because keywords have predefined meanings.

# %%
import keyword
print(keyword.kwlist)
print(len(keyword.kwlist))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %% [markdown]
# 4. Create email ids with the user inputs. in the following format -
# lastname.firstname@gmail.com

# %%
firstname = input("Enter your name:")
lastname = input("Enter your lastname:")
print(f"{lastname}.{firstname}@gmail.com")
# Out:
# Enter your name:govind
# Enter your lastname:devke
# devke.govind@gmail.com

# %% [markdown]
# 5. Try to print the following lines -
#   - Hi I'm Sunny
#   - My address is 22\3
#   - I earn 20$ daily.

# %%
print("""
Hi, I'm Sunny
My address is 22\\3
I earn 20$ daily.
""")
# Out:
# Hi, I'm Sunny
# My address is 22\3
# I earn 20$ daily.

# %% [markdown]
# 6. Take user input (name, address, date of birth etc) to fill a form for your college and print their email IDs.

# %%
name = input("Enter your name:")
address = input("Enter your address:")
date_of_birth = input("Enter your date of birth:")
print(f"{name}.{date_of_birth}@gmail.com")
# Out:
# Enter your name:sunil
# Enter your address:nashik
# Enter your date of birth:21oct
# sunil.21oct@gmail.com

# %% [markdown]
# 7. Convert the following -
#   - "22.4" into integer
#   - "22" into complex no.

# %%
A = input("Enter the value of A:")
B = input("Enter the value of B:")
A = float(A)
B = complex(B)
print(f"The value of A is{int(A)}")
print(f"The value of B is {B}")
# Out:
# Enter the value of A:22.4
# Enter the value of B:22
# The value of A is22
# The value of B is (22+0j)
