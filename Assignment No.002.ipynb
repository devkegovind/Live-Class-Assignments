# %% [markdown]
# # **ASSIGNMENT No.2**
# - ## **FSDS Batch 17 September 2022**

# %% [markdown]
# **1. What is indentation error? Why indentation is important? Give one simple example?**
# - Indentation error: it can occur when the tabs or spaces are not placed properly.
# - There will not be an issue if the interpreter does not find any issues with the spaces or tabs.
# - if there is an error due to indentation, it will come in between execution and can be a show stopper.
# - whitespaces is used for identation in python.

# %%
a = 1
if a > 10:
print("a is more than 10")
else:
print("a is less than 10")
# Out:
#   File "<ipython-input-1-4593effdc67f>", line 3
#     print("a is more than 10")
#         ^
# IndentationError: expected an indented block

# %%
a = 1
if a > 10:
  print("a is more than 10")
else:
  print("a is less than 10")
# Out:
# a is less than 10

# %%
class_started = bool(input("Hey friend, is class started?: [0-False/1-True]"))

if class_started == 1:
      print("Since class started...")
      print("Lets concentrate")
else:
      print("Since class is not started...")
      print("let's revise")
# Out:
# Hey friend, is class started?: [0-False/1-True]1
# Since class started...
# Lets concentrate

# %% [markdown]
# **2. Correct the following code and write the comment where you made the correction?**
#
#   ```python
#   class_started = bool(input("Hey friend, is class started?: [0-False/1-True]"))
#
#   if class_started:
#       print("Since class started...")
#       print("Lets concentrate")
#   else:
#       print("Since class is not started...")
#       print("let's revise")
#   ```
#
#   **HINT:** Refer your data type conversion class.

# %%
class_started = bool(int(input("Hey friend, is class started?: [0-False/1-True]")))

if class_started:
      print("Since class started...")
      print("Lets concentrate")
else:
      print("Since class is not started...")
      print("let's revise")
# Out:
# Hey friend, is class started?: [0-False/1-True]1
# Since class started...
# Lets concentrate

# %% [markdown]
# **3. Use if else condition to verify that dataype of `input()` method in python is always string.**

# %%
a = input("Enter the value of a: ")
if type(a) == str:
  print(f"The datatype of a:{a} is string.")
else:
  print(f"The datatype of a:{a} is not string.")
# Out:
# Enter the value of a: 78
# The datatype of a:78 is not string.

# %% [markdown]
# **4. Take 3 variables and assign integer values to them. Find the largest variable, by only using the if and else conditions.**

# %%
a = int(input("Enter the value of a: "))
b = int(input("Enter the value of b: "))
c = int(input("Enter the value of c: "))
if a >= b and a >= c:
  largest = a
elif b >= a and b >= c:
  largest = b  
else:
  largest = c
print(f"The largest variable is:{largest}.")
# Out:
# Enter the value of a: 55
# Enter the value of b: 47
# Enter the value of c: 89
# The largest variable is:89.

# %% [markdown]
# **5. What would be the solution?**
#
#     1. True
#     2. False
# ```python
#     a = 6
#     b = 10
#     print( not ( not a == 10 or not b == 10))
#
# ```
# - 2. False

# %% [markdown]
# **6. Find the answer as well as find out the reason behind the result?**
#
#
#   - case 1:
#  ```python
#         A = 5.0
#         B = 10/2
#         print(A is B)
#   ```
#     - case 2:
#   ```python
#         A = 5.0
#         B = int(10/2)
#         print(A is B)
#   ```
#     - case 3:
#   ```python
#         A = 5.0
#         B = float(10/2)
#         print(A is B)
#   ```

# %% [markdown]
# - case 1: False because memory block of value of A and B is different.
# - case 2: False because memory block of value of A and B is different.
# - Data type of variable A and B is also different.
# - case 3: False because memory block of value of A and B is different.

# %% [markdown]
# **7. Write a program that asks the user to enter a number. You should print out a message to the user, either “That number is divisible by either 3 or 5”, or “That number is not divisible by either 3 or 5”. Be sure to consider the data type of the input you are taking in from the user. Use a single if/else block to solve this problem.**

# %%
num = int(input("Enter the value of num: "))
if num % 3 == 0 or num % 5 == 0:
  print(f"That number {num} is divisible by either 3 or 5.")
else:
  print(f"That number {num} is not divisible by either 3 or 5.")
# Out:
# Enter the value of num: 8
# That number 8 is not divisible by either 3 or 5.

# %% [markdown]
# **8. Take user input for length and width. Then calculate the area of rectangle. Also print as per length and width whether its a square of rectangle.**

# %%
length = int(input("Enter the length of the rectangle: "))
width = int(input("Enter the width of the rectangle: "))
if length == width:
  print(f"its a square")
  print(f"Because the length:{length} and width {width} are same.")
  print(f"The area of square is:{length**2}.")
else:
  print(f"its a rectangle.")
  print(f"Because the length:{length} and width {width} are not same.")
  print(f"The area of rectangle is:{length * width}")
# Out:
# Enter the length of the rectangle: 34
# Enter the width of the rectangle: 65
# its a rectangle.
# Because the length:34 and width 65 are not same.
# The area of rectangle is:2210

# %%
length = int(input("Enter the length of the rectangle: "))
width = int(input("Enter the width of the rectangle: "))
if length == width:
  print(f"its a square")
  print(f"Because the length:{length} and width {width} of are same.")
  print(f"The area of square is:{length**2}.")
else:
  print(f"its a rectangle.")
  print(f"Because the length:{length} and width {width} are not same.")
  print(f"The area of rectangle is:{length * width}")
# Out:
# Enter the length of the rectangle: 30
# Enter the width of the rectangle: 30
# its a square
# Because the length:30 and width 30 of are same.
# The area of square is:900.

# %% [markdown]
# **9. Take two variable radius_1 and radius_2 and calculate the area of circle_1 and circle_2. Also print which circle has large area. If area is equal then print area is equal.**

# %%
radius_1 = int(input("Enter the radius of the circle_1: "))
radius_2 = int(input("Enter the radius of the circle_2: "))
area_of_circle_1 = 3.14 *(radius_1**2)
area_of_circle_2 = 3.14 *(radius_2**2) 
print(f"The area of circle_1 is:{area_of_circle_1}.")
print(f"The area of circle_2 is:{area_of_circle_2}.") 
if area_of_circle_1 >= area_of_circle_2:
  if area_of_circle_1 == area_of_circle_2:
    print(f"The area of both circles is equal.")
  else:
    print(f"The area of circle_1 is large area:{area_of_circle_1}")
else:
  print(f"The area of circle_2 is large area:{area_of_circle_2}")
# Out:
# Enter the radius of the circle_1: 10
# Enter the radius of the circle_2: 10
# The area of circle_1 is:314.0.
# The area of circle_2 is:314.0.
# The area of both circles is equal.

# %% [markdown]
# **10. Check whether a year is leap year or not. Use nested if...else to solve this problem. A leap year is exactly divisible by 4 except for century years (years ending with 00). The century year is a leap year only if it is perfectly divisible by 400.**

# %%
year = int(input("Enter the year: "))
if year % 4 == 0:
  print(f"The year {year} is leap year.")
  if year % 400 == 0:
    print(f"The year {year} is century yea.")
  else:
    print(f"The year {year} is not century year.")
else:
  print(f"The year {year} is not leap year.")
# Out:
# Enter the year: 1900
# The year 1900 is leap year.
# The year 1900 is not century year.
