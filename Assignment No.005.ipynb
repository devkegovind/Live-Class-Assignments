# %% [markdown]
# #**ASSIGNMENTS 005**
# ## **FSDS Batch 17 September 2022**

# %% [markdown]
# #### **1. On amazon website we have the following available items**
#
# ```python
# amazon_website = [("watch", 5000), ("phone", 10000), ("laptop", 50000), ("shirt", 1000)]
# ```
# Take the user input N no. of times and find out the total cost to be paid?
#
# OR
#
# You can ask the user quntity or the count of item?
#
# if the item is not present in the amazon website then print that item as out of stock and do add it total
#
#
# HINT: while, for loop.. indexing

# %%
amazon_website = [("watch", 5000), ("phone", 10000), ("laptop", 50000), ("shirt", 1000)]

N = int(input("Enter the item you want: "))

total_cost = 0

for i in range(N):
  user_item = input("enter the item you purchase: ")
  for item in amazon_website:
    if user_item in item[0]:
      #print(item[1])
      #print(f"{total_cost} = {total_cost} + {item[1]}")
      total_cost = total_cost + item[1]
      break
    else:
          print("item is as out of stock")

print(f"Total cost is: {total_cost}")
# Out:
# Enter the item you want: 1
# enter the item you purchase: phone
# item is as out of stock
# Total cost is: 10000

# %%
amazon_cart = [("watch", 5000), ("phone", 10000), ("laptop", 50000), ("shirt", 1000)]

print("""
'watch' = watch
'phone' = phone
'laptop' = laptop
'shirt' = shirt
'stop' = complete shopping""")

continue_shopping = True
total_cost = 0
while continue_shopping:
  user_item = input("Enter the item name: ").lower()
  if user_item == "stop":
    continue_shopping = False
  elif user_item == "watch":
    no_of_items = int(input("No. of item you want to purchase: "))
    print(f"{total_cost} = {total_cost} + {amazon_cart[0][1]}*{no_of_items}")
    total_cost = total_cost + amazon_cart[0][1]* no_of_items
  elif user_item == "phone":
    no_of_items = int(input("No. of item you want to purchase: "))
    print(f"{total_cost} = {total_cost} + {amazon_cart[1][1]}*{no_of_items}")
    total_cost = total_cost + amazon_cart[1][1] * no_of_items
  elif user_item == "laptop":
    no_of_items = int(input("No. of item you want to purchase: "))
    print(f"{total_cost} = {total_cost} + {amazon_cart[2][1]} * {no_of_items}")
    total_cost = total_cost + amazon_cart[2][1] * no_of_items
  elif user_item == "shirt":
    no_of_items = int(input("No. of item you want to purchase: "))
    print(f"{total_cost} = {total_cost} + {amazon_cart[3][1]} * {no_of_items}")
    total_cost = total_cost + amazon_cart[3][1] * no_of_items
  else:
    print("item is out of stock.")
    
print(f"Total_cost is: {total_cost}")
# Out:
# 'watch' = watch
# 'phone' = phone
# 'laptop' = laptop
# 'shirt' = shirt
# 'stop' = complete shopping
# Enter the item name: watch
# No. of item you want to purchase: 3
# 0 = 0 + 5000*3
# Enter the item name: phone
# No. of item you want to purchase: 2
# 15000 = 15000 + 10000*2
# Enter the item name: laptop
# No. of item you want to purchase: 1
# 35000 = 35000 + 50000 * 1
# Enter the item name: shirt
# No. of item you want to purchase: 0
# 85000 = 85000 + 1000 * 0
# Enter the item name: stop
# Total_cost is: 85000

# %% [markdown]
# #### **2. What will be the output of the following code snippet?**
#
# ```
# arr = [1, 2, 3, 4, 5, 6]
# for i in range(1, 6):
#     arr[i - 1] = arr[i]
# for i in range(0, 6):
#     print(arr[i], end = " ")
# ```

# %%
arr = [1, 2, 3, 4, 5, 6]
for i in range(1, 6):
    arr[i - 1] = arr[i]
for i in range(0, 6): 
    print(arr[i], end = " ")
# Out:
# 2 3 4 5 6 6

# %% [markdown]
# #### **3. Write a Python program to find the repeated items of a tuple.**

# %%
a = (1,3,3,4,5,6,7,4)

for i in a:
  j = a.count(i)
  if j > 1:
    print(f"{i} = {j} ---> It is repeated")
# Out:
# 3 = 2 ---> It is repeated
# 3 = 2 ---> It is repeated
# 4 = 2 ---> It is repeated
# 4 = 2 ---> It is repeated

# %% [markdown]
# ### **4. Replace last value of tuples in a list with 500. Try using list comprehension**
#
# Example -:
# ```
# Input -:
#
# [(10, 20, 40), (40, 50, 60), (70, 80, 90)]
#
# Output -:
# [(10, 20, 500), (40, 50, 500), (70, 80, 500)]
#
#
# ```

# %%
lst = [(10, 20, 40), (40, 50, 60), (70, 80, 90)]

ans = [i[:-1] + (500, ) for i in lst]

# %%
ans
# Out:
# [(10, 20, 500), (40, 50, 500), (70, 80, 500)]

# %%
lst = [(10, 20, 40), (40, 50, 60), (70, 80, 90)]
lst1 = list()
for i in lst:
  i = list(i)
  i[2] = 500
  i = tuple(i)
  lst1.append(i)
print(lst1)
# Out:
# [(10, 20, 500), (40, 50, 500), (70, 80, 500)]
